# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Inann\Desktop\pfe_plan\v4\03_extracted\SituationChap_LIGNES_BUDGETAIRES_TOTAL.xlsx')

# %%
df.groupby("Intitule").nunique()
# Out:
#                                                     Year  Chap  Chap_Intitule  \
# Intitule
# Abonnement et documentation                            6     1              1
# Achat d'articles de plomberie sanitaire, outill...     6     1              1
# Achat d'outillage, de matériel, de fournitures ...     6     1              1
# Achat de cadeaux présentés aux délégations             6     1              1
# Achat de carburants et lubrifiants                     6     1              1
# ...                                                  ...   ...            ...
# Taxes postales et frais d'affranchissement             6     1              1
# Traitements, salaires et indemnités permanentes...     6     1              1
# Travaux d'aménagement et d'installation                6     1              1
# Travaux de construction ou d'extension de bâtim...     6     1              1
# Versement aux comptes spéciaux du Trésor               5     2              2
#
# ...
